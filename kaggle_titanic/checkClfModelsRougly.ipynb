# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import StratifiedKFold
from IPython.display import display

import sys
sys.path.insert(0, 'G:/work/GitHub/ml_baseline_things/functions/')

import CheckClassificationModels as ccm

# %%
dataTrain, dataTarget, _ , dataTrainScaled, _, selectedFeatures = joblib.load('dumps_clean_data/dataDump.pkl')
dataTrain = dataTrain[selectedFeatures]
dataTrainScaled = dataTrainScaled[selectedFeatures]

# %% [markdown]
# ## задача этого ноута - построить кроссвалидацию + все начальные модели

# %% [markdown]
# ## Crossvalidation

# %%
#check if balanced or not
print ('check if balanced or not: {}'.format(float(sum(dataTarget))/len(dataTrain)))

#http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation-iterators
# checklist CV strategy
# данные приходят из i.i.d распределения?
# данные имеют временную зависимоть?
# данные имеют зависимость от группы? например, строки можно объединить в группы, где целевая переменная генерится по своему закону по каждой группе?
# может выделить искуственную группу от признака, от которого есть большая корреляция?
# есть ли смежные данные?

# checklist metrics - metrics should be choosen optimally
# Out:
# check if balanced or not: 0.3838383838383838

# %%
RS = 1
nSamples = len(dataTrain)

cvs = [StratifiedKFold(n_splits=i, random_state=RS, shuffle=True) for i in [2,4,6,10]]

dataTrainMods = [
    ['scaled', dataTrainScaled[:nSamples]],
    ['non-scaled', dataTrain[:nSamples]]
    ]

# %%
results = ccm.global_check_clf_models (dataTrainMods, dataTarget[:nSamples], cvs, RS, n_jobs = -1)#, debugMode=1)
for result in results:
    print('Iteration with dataMods={}, cv={}'.format(result[0],result[1]))
    display(result[2])
    print ('\n')
# Out:
# Total iterations will be perform = 8
# Iteration done
# Iteration done
# Iteration done
# Iteration done
# Iteration done
# Iteration done
# Iteration done
# Iteration done
# Congrats! All DONE. Total time is [mins]: 34.73
#
# Iteration with dataMods=scaled, cv=StratifiedKFold(n_splits=2, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 1           KNeighborsClassifier   0.817071  0.009896       10.00
# 11                      LightGBM   0.815950  0.011017       10.00
# 8                  XGBClassifier   0.814821  0.005404       10.00
# 3                             SVC  0.812576  0.005401       11.00
# 7   RandomForestClassifier (auto)  0.800244  0.017733       10.00
# 9         DecisionTreeClassifier   0.795745  0.008749       10.00
# 2                       SVClinear  0.793513  0.019970       10.00
# 5                LinearRegression  0.793510  0.017726       11.00
# 6             LogisticRegression   0.791263  0.015478       11.00
# 0             SGDClassifier model  0.776631  0.021575       10.00
# 10                    Perceptron   0.685794  0.042296       10.00
# 4                     GaussianNB   0.640752  0.090190       10.00
# 12                      TOTAL AVG  0.778156  0.022120       10.25
# Iteration with dataMods=non-scaled, cv=StratifiedKFold(n_splits=2, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 11                      LightGBM   0.815950  0.011017       10.00
# 8                  XGBClassifier   0.814821  0.005404       10.00
# 3                             SVC  0.802469  0.000222       10.00
# 7   RandomForestClassifier (auto)  0.800242  0.015488       10.00
# 9         DecisionTreeClassifier   0.795745  0.008749       10.00
# 2                       SVClinear  0.794636  0.021094       10.00
# 6             LogisticRegression   0.794629  0.014360       11.00
# 5                LinearRegression  0.793510  0.017726       11.00
# 1           KNeighborsClassifier   0.791248  0.002010       10.00
# 0             SGDClassifier model  0.764302  0.006999       11.00
# 10                    Perceptron   0.691417  0.052403       10.00
# 4                     GaussianNB   0.640752  0.090190       10.00
# 12                      TOTAL AVG  0.774977  0.020472       10.25
# Iteration with dataMods=scaled, cv=StratifiedKFold(n_splits=4, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 11                      LightGBM   0.818217  0.019911   16.000000
# 8                  XGBClassifier   0.818207  0.017299   15.000000
# 3                             SVC  0.817086  0.023477   17.000000
# 7   RandomForestClassifier (auto)  0.803628  0.012264   16.000000
# 9         DecisionTreeClassifier   0.799133  0.017124   16.000000
# 1           KNeighborsClassifier   0.796881  0.014352   16.000000
# 6             LogisticRegression   0.792417  0.019930   18.000000
# 2                       SVClinear  0.790165  0.018154   17.000000
# 5                LinearRegression  0.782282  0.006961   18.000000
# 0             SGDClassifier model  0.741933  0.029608   18.000000
# 10                    Perceptron   0.694876  0.059822   17.000000
# 4                     GaussianNB   0.666492  0.116246   16.000000
# 12                      TOTAL AVG  0.776776  0.029596   16.666667
# Iteration with dataMods=non-scaled, cv=StratifiedKFold(n_splits=4, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 11                      LightGBM   0.818217  0.019911        16.0
# 8                  XGBClassifier   0.818207  0.017299        16.0
# 3                             SVC  0.811491  0.028533        17.0
# 7   RandomForestClassifier (auto)  0.805880  0.014070        16.0
# 6             LogisticRegression   0.801396  0.014334        17.0
# 9         DecisionTreeClassifier   0.799133  0.017124        16.0
# 1           KNeighborsClassifier   0.794598  0.017635        16.0
# 2                       SVClinear  0.792427  0.019553        17.0
# 5                LinearRegression  0.782282  0.006961        18.0
# 0             SGDClassifier model  0.757563  0.038282        17.0
# 10                    Perceptron   0.745074  0.064390        17.0
# 4                     GaussianNB   0.666492  0.116246        15.0
# 12                      TOTAL AVG  0.782730  0.031195        16.5
# Iteration with dataMods=scaled, cv=StratifiedKFold(n_splits=6, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 3                             SVC  0.823810  0.023062   26.000000
# 11                      LightGBM   0.821581  0.021635   24.000000
# 8                  XGBClassifier   0.818210  0.025034   24.000000
# 9         DecisionTreeClassifier   0.799149  0.016551   24.000000
# 7   RandomForestClassifier (auto)  0.799126  0.020460  130.000000
# 6             LogisticRegression   0.793571  0.027040   26.000000
# 1           KNeighborsClassifier   0.791259  0.034685   22.000000
# 2                       SVClinear  0.789074  0.023824   25.000000
# 5                LinearRegression  0.781184  0.019269   22.000000
# 0             SGDClassifier model  0.748617  0.027531   24.000000
# 10                    Perceptron   0.724953  0.039607   22.000000
# 4                     GaussianNB   0.699188  0.070698   22.000000
# 12                      TOTAL AVG  0.782477  0.029116   32.583333
# Iteration with dataMods=non-scaled, cv=StratifiedKFold(n_splits=6, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 11                      LightGBM   0.823818  0.021923   24.000000
# 8                  XGBClassifier   0.818210  0.025034   22.000000
# 3                             SVC  0.811491  0.024277   22.000000
# 9         DecisionTreeClassifier   0.799149  0.016551   25.000000
# 6             LogisticRegression   0.798046  0.021363   27.000000
# 1           KNeighborsClassifier   0.798000  0.020669   25.000000
# 7   RandomForestClassifier (auto)  0.798000  0.021436   25.000000
# 2                       SVClinear  0.787956  0.025351   26.000000
# 5                LinearRegression  0.781184  0.019269   28.000000
# 0             SGDClassifier model  0.747483  0.040133   26.000000
# 10                    Perceptron   0.712732  0.045503   25.000000
# 4                     GaussianNB   0.699188  0.070698   24.000000
# 12                      TOTAL AVG  0.781271  0.029351   24.916667
# Iteration with dataMods=scaled, cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 3                             SVC  0.817061  0.027514   32.000000
# 11                      LightGBM   0.813691  0.024663   31.000000
# 8                  XGBClassifier   0.804689  0.015501   30.000000
# 7   RandomForestClassifier (auto)  0.795713  0.025641   32.000000
# 9         DecisionTreeClassifier   0.794651  0.022030   30.000000
# 6             LogisticRegression   0.791281  0.025432   33.000000
# 1           KNeighborsClassifier   0.787847  0.017313   30.000000
# 2                       SVClinear  0.784540  0.024287   31.000000
# 5                LinearRegression  0.781169  0.025065   32.000000
# 10                    Perceptron   0.721856  0.085966   30.000000
# 0             SGDClassifier model  0.705811  0.099712   32.000000
# 4                     GaussianNB   0.699358  0.087791   30.000000
# 12                      TOTAL AVG  0.774806  0.040076   31.083333
# Iteration with dataMods=non-scaled, cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#                             Model  Accuracy       Std  Time[secs]
# 3                             SVC  0.821568  0.026153   31.000000
# 11                      LightGBM   0.813691  0.024663   31.000000
# 8                  XGBClassifier   0.804689  0.015501   31.000000
# 6             LogisticRegression   0.801394  0.029834   32.000000
# 7   RandomForestClassifier (auto)  0.795713  0.025641   30.000000
# 9         DecisionTreeClassifier   0.794651  0.022030   33.000000
# 1           KNeighborsClassifier   0.786786  0.019717   30.000000
# 2                       SVClinear  0.785676  0.029629   30.000000
# 5                LinearRegression  0.781169  0.025065   33.000000
# 10                    Perceptron   0.750981  0.044256   31.000000
# 0             SGDClassifier model  0.739406  0.052072   32.000000
# 4                     GaussianNB   0.699358  0.087791   30.000000
# 12                      TOTAL AVG  0.781257  0.033529   31.166667

# %%
# имеет смысл потюнить SVM
