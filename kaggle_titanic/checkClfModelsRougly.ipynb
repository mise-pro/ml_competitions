# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from sklearn.externals import joblib
from sklearn.model_selection import StratifiedKFold
from IPython.display import display

import sys
sys.path.insert(0, 'modules/')

import check_classification_models as ccm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataTrain, dataTarget, _ , dataTrainScaled, _, selectedFeatures = joblib.load('dumps_clean_data/dataDump.pkl')
dataTrain = dataTrain[selectedFeatures]

# %% [markdown]
# ## задача этого ноута - построить кроссвалидацию + все начальные модели

# %% [markdown]
# ## Crossvalidation

# %%
#http://scikit-learn.org/stable/modules/cross_validation.html#cross-validation-iterators
# checklist CV strategy
# данные приходят из i.i.d распределения?
# данные имеют временную зависимоть?
# данные имеют зависимость от группы? например, строки можно объединить в группы, где целевая переменная генерится по своему закону по каждой группе?
# может выделить искуственную группу от признака, от которого есть большая корреляция?
# есть ли смежные данные?

# checklist metrics - metrics should be choosen optimally

# %%
RS = 1

cvs = [
    StratifiedKFold(n_splits = 5, shuffle=True, random_state=RS),
    StratifiedKFold(n_splits = 10, shuffle=True, random_state=RS)
    ]

dataTrainMods = [
    ['scaled', dataTrainScaled],
    ['non-scaled', dataTrain]
    ]

# %%
results = ccm.global_check_clf_models (dataTrainMods, dataTarget[:], cvs, RS, n_jobs = -1)#, debugMode=1)
for result in results:
    print('Iteration with dataMods={}, cv={}'.format(result[0],result[1]))
    display(result[2])
    print ('\n')
# Out:
# Total iterations will be perform = 4
# Congrats! All DONE. Total time is [mins]: 18.6
#
# Iteration witd dataMods=scaled, cv=StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
#                                     Model  Accuracy       Std  Time[secs]
# 3                                     SVC  0.808045  0.018971   20.000000
# 8                          XGBClassifier   0.805835  0.012075   19.000000
# 7   RandomForestClassifier (n_estim=1000)  0.804693  0.012258   23.000000
# 9                 DecisionTreeClassifier   0.800280  0.016237   19.000000
# 1                   KNeighborsClassifier   0.798014  0.016645   19.000000
# 6                     LogisticRegression   0.787927  0.017349   21.000000
# 2                               SVClinear  0.786810  0.017146   21.000000
# 5                        LinearRegression  0.784550  0.018917   21.000000
# 0                     SGDClassifier model  0.759868  0.040518   20.000000
# 10                            Perceptron   0.721445  0.062909   21.000000
# 4                             GaussianNB   0.686897  0.093498   19.000000
# 11                              TOTAL AVG  0.776760  0.029684   20.272727
# Iteration witd dataMods=non-scaled, cv=StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
#                                     Model  Accuracy       Std  Time[secs]
# 3                                     SVC  0.811409  0.010480   21.000000
# 8                          XGBClassifier   0.805835  0.012075   22.000000
# 7   RandomForestClassifier (n_estim=1000)  0.805816  0.011820   25.000000
# 9                 DecisionTreeClassifier   0.800280  0.016237   20.000000
# 6                     LogisticRegression   0.795792  0.017722   21.000000
# 1                   KNeighborsClassifier   0.792377  0.016555   20.000000
# 2                               SVClinear  0.786822  0.019711   20.000000
# 5                        LinearRegression  0.784550  0.018917   22.000000
# 10                            Perceptron   0.756422  0.020303   22.000000
# 0                     SGDClassifier model  0.739542  0.038291   20.000000
# 4                             GaussianNB   0.686897  0.093498   21.000000
# 11                              TOTAL AVG  0.778704  0.025055   21.272727
# Iteration witd dataMods=scaled, cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#                                     Model  Accuracy       Std  Time[secs]
# 3                                     SVC  0.817061  0.027514   30.000000
# 7   RandomForestClassifier (n_estim=1000)  0.808060  0.023439   31.000000
# 8                          XGBClassifier   0.804689  0.015501   27.000000
# 9                 DecisionTreeClassifier   0.794651  0.022030   28.000000
# 6                     LogisticRegression   0.791281  0.025432   31.000000
# 1                   KNeighborsClassifier   0.787847  0.017313   28.000000
# 2                               SVClinear  0.785663  0.025118   31.000000
# 5                        LinearRegression  0.781169  0.025065   31.000000
# 10                            Perceptron   0.721856  0.085966   31.000000
# 0                     SGDClassifier model  0.705811  0.099712   32.000000
# 4                             GaussianNB   0.699358  0.087791   27.000000
# 11                              TOTAL AVG  0.772495  0.041353   29.727273
# Iteration witd dataMods=non-scaled, cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
#                                     Model  Accuracy       Std  Time[secs]
# 3                                     SVC  0.821568  0.026153   32.000000
# 7   RandomForestClassifier (n_estim=1000)  0.808060  0.023439   31.000000
# 8                          XGBClassifier   0.804689  0.015501   28.000000
# 6                     LogisticRegression   0.801394  0.029834   32.000000
# 9                 DecisionTreeClassifier   0.794651  0.022030   29.000000
# 1                   KNeighborsClassifier   0.786786  0.019717   28.000000
# 2                               SVClinear  0.785676  0.029629   33.000000
# 5                        LinearRegression  0.781169  0.025065   32.000000
# 10                            Perceptron   0.750981  0.044256   30.000000
# 0                     SGDClassifier model  0.739406  0.052072   30.000000
# 4                             GaussianNB   0.699358  0.087791   27.000000
# 11                              TOTAL AVG  0.779431  0.034135   30.181818

# %%
RS = 100

cvs = [
    StratifiedKFold(n_splits = 5, shuffle=True, random_state=RS),
    StratifiedKFold(n_splits = 10, shuffle=True, random_state=RS)
    ]

dataTrainMods = [
    ['scaled', dataTrainScaled],
    ['non-scaled', dataTrain]
    ]

results = ccm.global_check_clf_models (dataTrainMods, dataTarget[:], cvs, RS, n_jobs = -1)#, debugMode=1)
for result in results:
    print('Iteration with dataMods={}, cv={}'.format(result[0],result[1]))
    display(result[2])
    print ('\n')
# Out:
# Total iterations will be perform = 4
# Iteration done
# Iteration done

# %%
# имеет смысл потюнить SVM
