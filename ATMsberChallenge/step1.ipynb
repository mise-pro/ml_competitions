# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier as xgb_s
from sklearn.metrics import f1_score
# %matplotlib inline
# %pylab inline
from matplotlib import pyplot as plt

from sklearn import cross_validation, datasets, linear_model, metrics
from sklearn.preprocessing import StandardScaler
from sklearn import ensemble, learning_curve, metrics 
import numpy as np
import xgboost as xgb
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\learning_curve.py:22: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
data_train_raw = pd.read_csv('E:\\ya_ATMchallenge\\train_data_prepared.csv', sep=';')
data_test_raw = pd.read_csv('E:\\ya_ATMchallenge\\test_data_prepared.csv', sep=';')
#data_train_raw.head()

# %% [markdown]
# Задачи, которые я собираюсь здесь решить:
# - визуализировать данные, а именно:
#  - графики
# - попытаться убрать лишние признаки и оценить те данные, на которые больше всего завязывается модель
# - (DONE) масштабирование признаков
# - (DONE) оставить в модели категориальные признаки
# - применить все известные мне алгоритмы для классификации
# - реализовать поиск по сетке

# %% [markdown]
# Задача: оставить в модели категориальные признаки

# %%
#смотрим, какие признаки объекты и их меняем на числа
#print('{:30} {}'.format('column', 'nunique'))
#for col in data_train_raw.dtypes[data_train_raw.dtypes == 'object'].index:
#    print('{:30} {}'.format(col, data_train_raw[col].nunique()))
    
data_train=data_train_raw.copy()
data_train['cash_in_out']=data_train.cash_in_out.apply(lambda x : 0 if x=='Cash_Out' else 1)
data_train['display_type']=data_train.display_type.apply(lambda x : 0 if x=='Buttons' else 1)
data_train['scanner_code_reader']=data_train.scanner_code_reader.apply(lambda x : 0 if x=='2D' else 1)

data_test=data_test_raw.copy()
data_test['cash_in_out']=data_test.cash_in_out.apply(lambda x : 0 if x=='Cash_Out' else 1)
data_test['display_type']=data_test.display_type.apply(lambda x : 0 if x=='Buttons' else 1)
data_test['scanner_code_reader']=data_test.scanner_code_reader.apply(lambda x : 0 if x=='2D' else 1)

# %%
#искуственное разбиение для проверок с бейзлайном
data_train_trainPart, data_train_testPart = data_train[data_train.period < 20], data_train[data_train.period > 19]

# %% [markdown]
# Задача - отмасштабировать признаки

# %%
#стандартный scaler
scaler = StandardScaler()
data_train_target = data_train.target
data_train = scaler.fit_transform(data_train.drop(['target', 'period'], axis=1))
data_test = scaler.transform(data_test.drop(['period'], axis=1))

data_train_trainPart_target = data_train_trainPart.target
data_train_testPart_target = data_train_testPart.target
data_train_trainPart = scaler.fit_transform(data_train_trainPart.drop(['target', 'period'], axis=1))
data_train_testPart = scaler.transform(data_train_testPart.drop(['target','period'], axis=1))

# %% [markdown]
# #### RidgeClassifier + LogisticRegression
# Стандартные настройки

# %%
#создание объекта - классификатора
ridge_classifier = linear_model.RidgeClassifier(random_state = 1)
ridge_scoring = cross_validation.cross_val_score(ridge_classifier, data_train, data_train_target, scoring = 'f1', cv = 10, n_jobs = -1)
print (ridge_scoring)
print ('Ridge mean: {}, max:{}, min:{}, std:{}'.format(ridge_scoring.mean(), ridge_scoring.max(), 
                                                     ridge_scoring.min(), ridge_scoring.std()))

# %%
log_regressor = linear_model.LogisticRegression(random_state = 1, n_jobs=-1)
lr_scoring = cross_validation.cross_val_score(log_regressor, data_train, data_train_target, scoring = 'f1', cv = 10, n_jobs = -1)
print (lr_scoring)
print ('Log mean: {}, max:{}, min:{}, std:{}'.format(lr_scoring.mean(), lr_scoring.max(), 
                                                   lr_scoring.min(), lr_scoring.std()))

# %% [markdown]
# Теперь попробуем метрику f1 + StratifiedShuffleSplit

# %%
scorer = metrics.make_scorer(metrics.f1_score)
cv_strategy = cross_validation.StratifiedShuffleSplit(data_train_target, n_iter = 20 , test_size = 0.3, random_state = 1)
ridge_scoring = cross_validation.cross_val_score(ridge_classifier, data_train, data_train_target, scoring = scorer, cv = cv_strategy, n_jobs = -1)
lr_scoring = cross_validation.cross_val_score(log_regressor, data_train, data_train_target, scoring = scorer, cv = cv_strategy, n_jobs = -1)

# %%
print (ridge_scoring)
print ('Ridge mean:{}, max:{}, min:{}, std:{}'.format(ridge_scoring.mean(), ridge_scoring.max(), 
                                                     ridge_scoring.min(), ridge_scoring.std()))
print (lr_scoring)
print ('Log mean:{}, max:{}, min:{}, std:{}'.format(lr_scoring.mean(), lr_scoring.max(), 
                                                   lr_scoring.min(), lr_scoring.std()))

# %% [markdown]
# Качество выросло совсем чуть, второй знак после запятой. Попробуем регуляризацию l1 в lr

# %%
log_regressor = linear_model.LogisticRegression(random_state = 1, n_jobs=-1, penalty='l1')
lr_scoring = cross_validation.cross_val_score(log_regressor, data_train, data_train_target, scoring = scorer, cv = cv_strategy, n_jobs = -1)
print (lr_scoring)
print ('С регуляризацией l1: Log mean:{}, max:{}, min:{}, std:{}'.format(lr_scoring.mean(), lr_scoring.max(), 
                                                   lr_scoring.min(), lr_scoring.std()))

# %% [markdown]
# Чуть подросло качество еще, +0,03. Пробуем SGD + смотрим отбор параметров.
# #### SGDClassifier

# %%
SGDClassifier = linear_model.SGDClassifier(penalty = 'l2', n_jobs = -1)
SGD_scoring = cross_validation.cross_val_score(SGDClassifier, data_train, data_train_target, scoring = scorer, cv = cv_strategy, n_jobs = -1)
print ('SGD с регуляризацией l1: Log mean:{}, max:{}, min:{}, std:{}'.format(SGD_scoring.mean(), SGD_scoring.max(), 
                                                   SGD_scoring.min(), SGD_scoring.std()))

# %% [markdown]
# С 2мя регуляризациями качество sgd хуже предыдущих.

# %% [markdown]
# ### Проведем первичное знакомство с обзором признаков через sgd с регуляризацией l1

# %%
SGDClassifier = linear_model.SGDClassifier(penalty = 'l1', n_jobs = -1, random_state = 1)
SGDClassifier.fit(data_train_trainPart, data_train_trainPart_target)
metrics.f1_score(data_train_testPart_target, SGDClassifier.predict(data_train_testPart))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# 0.6088066368857691

# %% [markdown]
# Коэффициенты перед признаками:

# %%
coef_weights = np.fromiter(SGDClassifier.coef_[0], dtype=float)
features_name = np.array(data_train_raw.columns.drop(['period','target']))
sorted(zip(features_name, coef_weights), key=lambda x: x[1])[::-1]
# Out:
# [('non_related_to_transactions_gr5', 156.97429744031575),
#  ('avg_mcrw_error_gr5', 156.97429744031552),
#  ('non_related_to_status_gr5', 156.97429744031552),
#  ('non_related_total_errors_gr5', 156.9742974403154),
#  ('related_to_non_related_gr5', 156.97429744031507),
#  ('related_to_non_related_gr1', 148.90602908747476),
#  ('avg_hasp_error', 146.90600562637),
#  ('related_to_non_related', 143.7543632855014),
#  ('prr_error_by_disticnt_day_gr3', 136.77116285205037),
#  ('non_related_total_errors_prev4', 121.14477570502898),
#  ('non_related_to_transactions_prev5', 113.3575140095835),
#  ('non_related_total_errors_prev1', 111.22358869789173),
#  ('avg_bna_accept_count_gr3', 108.92348941191482),
#  ('avg_bna_error_gr2', 104.86656339444335),
#  ('days_since_last_cardreader_error_gr4', 101.54643738526455),
#  ('days_since_last_bna_error_gr4', 82.12996431644657),
#  ('avg_ndc_error_prev3', 80.00000765489914),
#  ('avg_cardreader_error_gr4', 75.25303544744678),
#  ('related_to_non_related_prev5', 74.7839836724246),
#  ('avg_bna_return_count_gr2', 74.00116330502377),
#  ('hours_since_last_cardreader_error_prev4', 73.34743715692062),
#  ('cash_in_out', 72.85220201584168),
#  ('avg_cdm_dispense_status_error_prev3', 70.96010999796565),
#  ('avg_cdm_delivery_status_error_gr2', 67.15387263040083),
#  ('related_to_transactions_prev1', 66.72520231250827),
#  ('avg_cdm_dispense_amount_distinct_day', 65.5172766602404),
#  ('avg_bna_accept_status_null_gr4', 63.72691686543128),
#  ('avg_mcrw_error_gr3', 59.998109634225806),
#  ('avg_ndc_error_gr3', 59.998109634225806),
#  ('non_related_to_status_gr3', 59.998109634225806),
#  ('non_related_total_errors_gr3', 59.998109634225635),
#  ('related_to_non_related_gr3', 59.998109634225635),
#  ('non_related_total_errors_gr2', 59.998109634225635),
#  ('related_to_non_related_gr2', 59.998109634225635),
#  ('avg_mcrw_error_gr2', 59.99810963422555),
#  ('avg_ndc_error_gr2', 59.99810963422555),
#  ('non_related_to_status_gr2', 59.99810963422555),
#  ('non_related_to_transactions_gr2', 59.998109634225514),
#  ('non_related_to_transactions_gr3', 59.99810963422527),
#  ('avg_cdm_delivery_status_unknown_gr4', 58.903612884583254),
#  ('non_related_to_transactions_prev2', 56.064173113531034),
#  ('last_error_cardreader_relative_prev5', 55.24353121721696),
#  ('hours_since_last_bna_error_prev4', 54.46720533522105),
#  ('last_error_cardreader_relative_gr3', 54.24837063008887),
#  ('days_since_last_cdm_error_gr5', 54.24641320596344),
#  ('bna_error_by_disticnt_day_prev3', 52.705736279844224),
#  ('avg_bna_return_count_gr5', 51.15517260137411),
#  ('avg_bna_vault_count_gr3', 50.9731998341214),
#  ('avg_cdm_error_gr2', 50.2327887521649),
#  ('avg_cdm_delivery_status_unknown_gr1', 50.04035245691732),
#  ('bna_error_by_day_prev2', 47.75602632901229),
#  ('non_related_to_status_prev3', 47.21084517368608),
#  ('transactions_count', 46.96360447233828),
#  ('avg_card_number_prev4', 46.07318586660451),
#  ('avg_cdm_dispense_count_distinct_day_gr1', 46.01573040769598),
#  ('avg_bna_return_count_distinct_day_prev4', 45.83869308674243),
#  ('avg_bna_return_count_distinct_day_prev1', 45.45761057288999),
#  ('status_count_prev4', 45.39249193204118),
#  ('last_error_cdm_relative_prev3', 45.3858216054545),
#  ('avg_bna_error_prev2', 44.588304701134305),
#  ('last_error_bna_relative_gr3', 44.58249560553143),
#  ('status_to_transactions_gr5', 43.6957038562113),
#  ('avg_cdm_delivery_status_unknown_distinct_day_gr4', 43.46591536818832),
#  ('cdm_error_by_day_gr4', 43.039847345797234),
#  ('avg_session_error_count_gr2', 42.548006943410975),
#  ('last_error_cardreader_relative_gr5', 42.014256258209244),
#  ('avg_cdm_delivery_status_unknown_distinct_day_prev4', 41.917097902432744),
#  ('last_error_prr_relative_gr4', 41.16887465672602),
#  ('avg_bna_vault_count_gr4', 40.64191636109148),
#  ('avg_bna_accept_count_gr4', 40.36960587788109),
#  ('cardreader_error_by_day_gr5', 40.029579711851135),
#  ('avg_front_prepare_count_prev4', 39.58574630922033),
#  ('avg_receipt_confirm_count_gr3', 39.297926658166666),
#  ('bna_error_by_day_gr1', 39.082927902571214),
#  ('avg_cdm_dispense_amount_distinct_day_gr4', 38.99722495570414),
#  ('cdm_error_by_day', 38.706957722478656),
#  ('avg_bna_accept_status_null_gr5', 38.696008350394514),
#  ('avg_bna_accept_count_gr2', 38.62684370592655),
#  ('prr_error_by_day_gr3', 38.37122226446642),
#  ('avg_receipt_confirm_count_prev1', 38.35865516097837),
#  ('status_count_prev5', 38.01975236306362),
#  ('avg_front_prepare_count_distinct_day_gr3', 37.76600811540155),
#  ('avg_cdm_delivery_count_distinct_day_gr1', 37.667369214757585),
#  ('prr_error_by_disticnt_day_prev2', 36.69173392413981),
#  ('avg_cardreader_error', 36.64249633062212),
#  ('days_since_last_cdm_error_gr3', 35.81114681316729),
#  ('avg_bna_return_count_gr1', 35.58278583555615),
#  ('avg_ndc_error_prev5', 35.556390163819664),
#  ('total_errors', 35.38725626244343),
#  ('error_per_day', 35.38725626244339),
#  ('avg_cdm_delivery_status_unknown_prev3', 35.08273303942372),
#  ('related_total_errors', 34.71544489537315),
#  ('avg_card_number_distinct_day_gr5', 34.38597443643294),
#  ('avg_session_error_count_prev2', 34.33873612036818),
#  ('avg_bna_return_count_distinct_day_gr5', 34.16601494634768),
#  ('avg_bna_vault_count_distinct_day_prev2', 34.110770735730306),
#  ('avg_bna_vault_count_gr2', 33.889957163052436),
#  ('hours_since_last_cardreader_error_gr4', 33.787534667376505),
#  ('hours_since_last_cardreader_error_prev5', 33.38848166991219),
#  ('avg_receipt_confirm_count_gr5', 33.26795777835508),
#  ('avg_cdm_delivery_status_unknown_gr3', 32.55543201335888),
#  ('days_since_last_bna_error_gr1', 32.374233498560685),
#  ('days_since_last_cardreader_error_gr5', 32.214751287000034),
#  ('days_since_last_cdm_error_prev2', 32.16673429599577),
#  ('cardreader_error_by_day_prev5', 31.85431069463014),
#  ('avg_hasp_error_prev3', 31.631514051350216),
#  ('avg_session_error_count_distinct_day_gr2', 31.625927202639957),
#  ('bna_error_by_disticnt_day_gr3', 31.598045271245493),
#  ('avg_cdm_error_prev1', 31.16818049597145),
#  ('non_related_to_transactions_prev4', 30.637639081419877),
#  ('hours_since_last_cdm_error_prev5', 30.602085127928085),
#  ('avg_mcrw_error_prev4', 30.58931825434199),
#  ('avg_session_error_count_gr1', 30.039618966039413),
#  ('avg_card_capture_count_distinct_day_gr2', 29.584066378106648),
#  ('cdm_error_by_day_gr3', 29.467733252081405),
#  ('related_total_errors_prev2', 29.114036015286267),
#  ('avg_bna_return_count_prev2', 29.094052595426817),
#  ('days_since_last_cdm_error_gr1', 29.050847560823374),
#  ('prr_error_by_disticnt_day_gr5', 29.047507618656017),
#  ('cdm_label_prev2', 28.778105440190497),
#  ('prr_error_by_day_prev1', 28.61076865979438),
#  ('error_per_day_prev2', 28.330326589048322),
#  ('total_errors_prev2', 28.330326589048294),
#  ('related_to_status_gr2', 28.28886448520595),
#  ('last_error_cdm_relative_gr1', 28.226184375671824),
#  ('avg_cdm_delivery_status_unknown_prev5', 28.07137177681029),
#  ('days_since_last_prr_error_gr1', 28.06966851267954),
#  ('avg_bna_return_count', 27.800142982264813),
#  ('transactions_count_gr3', 27.693807589559785),
#  ('avg_prr_error_prev5', 27.41175872080172),
#  ('prr_error_by_day', 27.355813695423407),
#  ('last_error_cardreader_relative', 27.343942843061576),
#  ('avg_receipt_confirm_count_prev4', 26.788816833382672),
#  ('avg_cdm_error_gr3', 26.560711478331328),
#  ('bna_error_by_disticnt_day_gr1', 26.321395255209325),
#  ('cardreader_error_by_day_prev2', 26.182085800141454),
#  ('days_since_last_bna_error_prev3', 26.07933767438376),
#  ('avg_session_error_count_prev1', 26.034869825280516),
#  ('bna_error_by_day_prev4', 25.67875514831607),
#  ('last_error_prr_relative_gr1', 25.547647209759383),
#  ('avg_cdm_error_prev3', 25.518175913858578),
#  ('avg_card_number_distinct_day_prev1', 25.506904970546525),
#  ('avg_bna_error_gr4', 25.35534514565947),
#  ('avg_epp_error_prev1', 25.276469939195387),
#  ('last_error_cardreader_relative_prev3', 25.272545446044116),
#  ('distinct_days_prev4', 25.113197442345513),
#  ('avg_receipt_confirm_count_distinct_day_prev1', 24.814978947647248),
#  ('avg_cdm_delivery_status_error', 24.71691210928129),
#  ('avg_card_capture_count_distinct_day_prev1', 24.571265605531202),
#  ('transactions_count_prev1', 24.498604396530382),
#  ('avg_cardreader_error_gr1', 24.217824115831608),
#  ('last_error_cardreader_relative_gr2', 24.071146578893188),
#  ('avg_prr_error_prev1', 23.758675290511203),
#  ('avg_cdm_delivery_status_unknown_gr2', 23.725535113311956),
#  ('last_error_cardreader_relative_gr1', 23.679116807477598),
#  ('status_to_transactions_gr4', 23.547635641915246),
#  ('avg_cdm_delivery_status_null_gr4', 23.25881211589708),
#  ('distinct_days_prev3', 23.095017361617735),
#  ('avg_bna_vault_count_distinct_day', 23.07923675713618),
#  ('avg_cdm_delivery_status_unknown_distinct_day_gr2', 22.65535855790686),
#  ('status_to_transactions_prev5', 22.569614575346602),
#  ('cdm_error_by_disticnt_day_gr3', 22.564828224402728),
#  ('bna_error_by_disticnt_day', 22.53688155302076),
#  ('days_since_last_cdm_error_prev1', 22.327080715102547),
#  ('avg_card_capture_count_prev4', 22.222232829330693),
#  ('cardreader_error_by_day_gr2', 22.16918069127284),
#  ('avg_front_prepare_count_prev5', 22.062335914463517),
#  ('avg_cdm_dispense_amount_prev5', 21.69462578777648),
#  ('non_related_to_transactions', 21.68830500526636),
#  ('avg_reply_count_distinct_day_prev3', 21.15440577210935),
#  ('transactions_count_gr4', 21.073548017995577),
#  ('last_error_prr_relative_gr5', 20.947657589262956),
#  ('avg_cdm_delivery_count_prev1', 20.91051083410928),
#  ('avg_cdm_delivery_status_ok_prev1', 20.823779419501626),
#  ('hours_since_last_prr_error_gr1', 20.454756966477163),
#  ('hours_since_last_cdm_error_prev3', 20.356399140539413),
#  ('avg_command_copletion_count_distinct_day_prev3', 20.292999606721672),
#  ('avg_request_count_distinct_day_prev3', 20.278730807878524),
#  ('avg_card_capture_count_distinct_day_gr1', 19.957602641470775),
#  ('avg_card_capture_count_prev2', 19.940957519156978),
#  ('avg_cdm_dispense_count_gr1', 19.888926483928827),
#  ('days_since_last_bna_error_gr3', 19.854318493738063),
#  ('avg_cdm_dispense_status_null_prev4', 19.743281631677128),
#  ('cdm_label', 19.56397886542686),
#  ('days_since_last_cdm_error_gr2', 19.382219606208757),
#  ('avg_bna_accept_count_distinct_day', 19.137226338067777),
#  ('avg_dispence_currency_810_prev1', 18.90544644633596),
#  ('avg_cdm_dispense_status_ok_prev1', 18.90544644633596),
#  ('related_to_transactions_prev4', 18.751819692708136),
#  ('prr_error_by_day_prev3', 18.586170179334264),
#  ('days_since_last_bna_error_gr2', 18.564634712335028),
#  ('avg_session_error_count_prev4', 18.389165805514562),
#  ('avg_card_number_gr5', 18.385583931682852),
#  ('status_to_transactions_gr2', 18.184433149377142),
#  ('avg_dispence_currency_0_gr4', 18.040818316898644),
#  ('total_errors_gr4', 17.984958933219467),
#  ('error_per_day_gr4', 17.98495893321946),
#  ('avg_cdm_dispense_status_null_gr4', 17.73551191710081),
#  ('avg_cardreader_error_prev3', 17.71986763109544),
#  ('last_error_cdm_relative_prev4', 17.69656416598059),
#  ('related_to_transactions_gr1', 17.5756004217898),
#  ('avg_bna_error_prev4', 17.496836060617657),
#  ('avg_dispence_currency_0_prev4', 17.19674122631013),
#  ('days_since_last_bna_error_prev4', 17.15689972878165),
#  ('avg_bna_return_count_prev1', 16.909264669864253),
#  ('avg_cdm_delivery_status_null_gr3', 16.898618587053654),
#  ('avg_bna_accept_count_distinct_day_prev2', 16.760341996102674),
#  ('avg_cdm_delivery_status_error_prev3', 16.685990033168626),
#  ('avg_front_prepare_count', 16.644712652133034),
#  ('avg_bna_return_count_distinct_day_gr1', 16.601837291123616),
#  ('avg_cdm_dispense_status_error', 16.425341290596734),
#  ('related_to_status_gr5', 16.35974135786965),
#  ('avg_cdm_delivery_status_error_gr1', 16.327354509988428),
#  ('avg_cdm_dispense_count_gr5', 16.29057256937071),
#  ('avg_bna_return_count_distinct_day_prev5', 16.25513870768216),
#  ('hours_since_last_bna_error_prev1', 16.213966436468407),
#  ('related_to_transactions_prev3', 16.204457116167255),
#  ('avg_cdm_dispense_status_null_gr3', 16.137557376850225),
#  ('days_since_last_prr_error_prev4', 15.972911379095269),
#  ('avg_dispence_currency_0_gr3', 15.92163124767628),
#  ('bna_error_by_disticnt_day_prev1', 15.906096878216337),
#  ('avg_card_number_gr3', 15.834957223185311),
#  ('avg_cdm_dispense_status_error_gr3', 15.779361211570503),
#  ('related_to_status_prev4', 15.766901914363812),
#  ('avg_cdm_delivery_status_unknown_distinct_day_prev2', 15.486421645199622),
#  ('distinct_days_gr4', 15.469948162755971),
#  ('total_errors_gr3', 15.232531855532857),
#  ('error_per_day_gr3', 15.232531855532779),
#  ('avg_card_number_distinct_day_gr3', 14.998326429485315),
#  ('transactions_count_gr1', 14.96708657914943),
#  ('status_count_gr2', 14.96517849878502),
#  ('last_error_prr_relative_prev3', 14.914195408480245),
#  ('related_to_transactions_gr2', 14.832207377934381),
#  ('avg_card_capture_count_prev5', 14.735031705555496),
#  ('avg_cdm_delivery_status_not_taken_gr4', 14.511436669400368),
#  ('total_errors_prev4', 14.456883694202448),
#  ('error_per_day_prev4', 14.456883694202354),
#  ('hours_since_last_prr_error_prev1', 14.157706148116583),
#  ('avg_bna_accept_count_distinct_day_prev1', 14.126588291376297),
#  ('avg_bna_vault_count_distinct_day_prev1', 13.941681995533843),
#  ('avg_cdm_error_prev4', 13.935545011280883),
#  ('avg_bna_return_count_distinct_day', 13.78364099746856),
#  ('avg_cdm_delivery_count_distinct_day_prev1', 13.615837412467421),
#  ('days_since_last_prr_error_prev2', 13.578976303731558),
#  ('cardreader_error_by_day', 13.564507992842056),
#  ('avg_ndc_error_prev2', 13.552518823242007),
#  ('non_related_total_errors', 13.313583822764691),
#  ('hours_since_last_cdm_error_prev1', 12.970434665583138),
#  ('avg_cdm_delivery_status_null_prev4', 12.90771959649041),
#  ('avg_cdm_dispense_amount_distinct_day_prev1', 12.680003373037849),
#  ('avg_card_capture_count_gr5', 12.661292138798034),
#  ('related_to_status_prev5', 12.582926881926067),
#  ('avg_reply_count_distinct_day_gr4', 12.568687821327952),
#  ('avg_receipt_confirm_count_distinct_day_prev4', 12.321244912665993),
#  ('last_error_bna_relative_gr4', 12.304245916303548),
#  ('avg_receipt_confirm_count_distinct_day_gr3', 12.076820406851983),
#  ('cdm_error_by_disticnt_day_prev2', 12.06123361169717),
#  ('avg_cdm_dispense_count_prev1', 11.99841242117365),
#  ('avg_cdm_delivery_status_unknown_prev1', 11.994043246765797),
#  ('related_to_transactions_gr5', 11.96999432504191),
#  ('related_total_errors_gr4', 11.880031466751221),
#  ('avg_cdm_dispense_status_error_prev2', 11.83364348938733),
#  ('avg_cdm_delivery_count_distinct_day_prev5', 11.705904615086295),
#  ('avg_request_count_distinct_day_gr4', 11.588572486505033),
#  ('hours_since_last_prr_error_gr2', 11.58288862607513),
#  ('avg_cdm_delivery_status_not_taken', 11.442092817876977),
#  ('prr_error_by_disticnt_day_gr1', 11.429497693639343),
#  ('avg_command_copletion_count_distinct_day_gr4', 11.38728351794839),
#  ('avg_cdm_delivery_status_error_prev2', 11.065365576410322),
#  ('avg_request_count', 11.032700347595188),
#  ('avg_cdm_dispense_amount_distinct_day_prev2', 10.807974290126069),
#  ('avg_reply_count', 10.797768974160114),
#  ('avg_command_completion_count', 10.705825297188373),
#  ('avg_cdm_error_gr4', 10.613156282317448),
#  ('avg_cdm_dispense_count_distinct_day_prev1', 10.590514433051396),
#  ('cdm_label_prev3', 10.502507012878072),
#  ('cardreader_error_by_day_prev3', 10.374400809317939),
#  ('avg_dispence_currency_810_gr1', 10.341387865194022),
#  ('avg_cdm_dispense_status_ok_gr1', 10.341387865194022),
#  ('avg_card_capture_count_distinct_day_prev3', 10.206732065960114),
#  ('days_since_last_cardreader_error_prev4', 10.15212711501252),
#  ('avg_cdm_delivery_status_unknown', 10.042056618942768),
#  ('avg_receipt_confirm_count_prev5', 9.97256616298183),
#  ('avg_cdm_delivery_count_gr1', 9.91033239387739),
#  ('avg_cdm_delivery_status_ok_gr1', 9.877672884951576),
#  ('avg_bna_accept_count_distinct_day_gr3', 9.36475691552423),
#  ('avg_cdm_delivery_count_prev5', 9.295006811023221),
#  ('bna_error_by_day_prev5', 9.251256025991523),
#  ('avg_bna_accept_count_prev4', 9.226377647431338),
#  ('avg_cdm_delivery_status_ok_prev5', 9.127435571336925),
#  ('avg_card_number_distinct_day_gr4', 9.126652123388562),
#  ('avg_session_error_count_prev3', 9.11319465722148),
#  ('avg_cdm_dispense_count_distinct_day_prev5', 9.066949476740309),
#  ('avg_cdm_delivery_status_null_prev2', 8.99524093075053),
#  ('avg_request_count_distinct_day_prev2', 8.946134662121544),
#  ('avg_command_copletion_count_distinct_day_prev2', 8.933343030454282),
#  ('last_error_cardreader_relative_prev2', 8.871746025255462),
#  ('avg_bna_accept_status_null_prev1', 8.80835288167151),
#  ('prr_error_by_day_prev5', 8.80033886252939),
#  ('avg_dispence_currency_0_prev2', 8.7988308113594),
#  ('related_total_errors_prev4', 8.650750693318429),
#  ('last_error_cdm_relative_gr4', 8.63413872293084),
#  ('total_errors_prev1', 8.608093067634325),
#  ('error_per_day_prev1', 8.6080930676343),
#  ('status_count_prev1', 8.579181987188132),
#  ('days_since_last_cdm_error_prev3', 8.496637686649752),
#  ('status_count_gr3', 8.42624530396422),
#  ('avg_bna_error_prev5', 8.38484106019149),
#  ('last_error_cdm_relative_gr5', 8.229467172087213),
#  ('avg_reply_count_gr2', 8.179328209654166),
#  ('avg_cdm_dispense_status_null_prev2', 8.110690864360985),
#  ('avg_card_capture_count_gr4', 8.017541601103872),
#  ('distinct_days_gr2', 7.986081588767057),
#  ('avg_card_number_prev1', 7.935219447708352),
#  ('avg_session_error_count_distinct_day_prev5', 7.881710620203068),
#  ('status_to_transactions_prev2', 7.757607469594651),
#  ('avg_cdm_error_gr5', 7.727702719082311),
#  ('hours_since_last_bna_error_prev2', 7.65470479150109),
#  ('days_since_last_prr_error', 7.581089438539941),
#  ('avg_request_count_gr2', 7.391011215322488),
#  ('avg_reply_count_distinct_day_prev2', 7.3751814352157705),
#  ('cardreader_error_by_day_prev4', 7.36396484900442),
#  ('hours_since_last_bna_error_gr4', 7.151221059822783),
#  ('avg_command_completion_count_gr2', 7.060704196966121),
#  ('avg_dispence_currency_810_prev5', 6.924013352553317),
#  ('avg_cdm_dispense_status_ok_prev5', 6.924013352553317),
#  ('avg_card_capture_count', 6.77897312660898),
#  ('prr_error_by_day_prev4', 6.734232162051695),
#  ('avg_request_count_gr4', 6.70034867799426),
#  ('avg_card_capture_count_distinct_day', 6.610999777986276),
#  ('days_since_last_cardreader_error_gr2', 6.610095726675835),
#  ('avg_card_number_distinct_day_prev2', 6.552628281384637),
#  ('avg_cdm_delivery_count', 6.477529765965964),
#  ('avg_cdm_delivery_status_ok', 6.310628652912723),
#  ('days_since_last_prr_error_prev1', 6.288484823849522),
#  ('avg_front_prepare_count_gr5', 6.139330000374921),
#  ('avg_reply_count_gr4', 6.132646944829908),
#  ('avg_command_completion_count_gr4', 6.110538601086985),
#  ('avg_cdm_dispense_count', 6.102314056333718),
#  ('bna_error_by_day_gr5', 6.002797167922947),
#  ('avg_cdm_delivery_count_distinct_day_prev4', 5.996275011046231),
#  ('avg_cdm_delivery_status_ok_gr5', 5.878814040629138),
#  ('avg_reply_count_distinct_day_gr2', 5.753607380180256),
#  ('avg_cdm_delivery_count_gr5', 5.735030297494623),
#  ('avg_cdm_delivery_status_not_taken_prev1', 5.725420199955673),
#  ('avg_cdm_dispense_amount_distinct_day_gr1', 5.539896218106594),
#  ('avg_dispence_currency_810_gr5', 5.408336589393011),
#  ('avg_cdm_dispense_status_ok_gr5', 5.408336589393011),
#  ('avg_front_prepare_count_distinct_day_gr2', 5.2125678091783),
#  ('cdm_error_by_day_prev2', 5.173254453201911),
#  ('hours_since_last_prr_error_prev3', 5.130127101924424),
#  ('last_error_cardreader_relative_gr4', 5.09378252290166),
#  ('avg_receipt_confirm_count_distinct_day_prev2', 5.091704002679465),
#  ('avg_bna_return_count_gr4', 4.878268314664871),
#  ('avg_dispence_currency_810', 4.8275702249080386),
#  ('avg_cdm_dispense_status_ok', 4.8275702249080386),
#  ('avg_dispence_currency_0_prev3', 4.755624966875146),
#  ('hours_since_last_cdm_error_gr1', 4.610025741659024),
#  ('related_to_non_related_prev2', 4.607874204811143),
#  ('avg_request_count_distinct_day_gr2', 4.481702238659365),
#  ('avg_command_copletion_count_distinct_day_gr2', 4.44755991867018),
#  ('prr_error_by_disticnt_day_gr4', 4.259560871079026),
#  ('avg_cdm_dispense_count_distinct_day_prev4', 4.203858174604889),
#  ('related_to_transactions_prev2', 4.172084525114467),
#  ('cdm_label_prev1', 4.101988643276039),
#  ('avg_card_capture_count_prev3', 4.057475252022229),
#  ('avg_reply_count_distinct_day', 4.048014688464031),
#  ('avg_receipt_confirm_count_distinct_day_gr5', 3.937019564613644),
#  ('avg_request_count_distinct_day', 3.802860506762228),
#  ('avg_command_copletion_count_distinct_day', 3.5646167109451965),
#  ('related_total_errors_prev5', 3.5432364107716574),
#  ('prr_error_by_disticnt_day_prev4', 3.477525135071261),
#  ('avg_card_number_distinct_day', 3.467388990642196),
#  ('avg_epp_error_prev3', 3.430077660124324),
#  ('avg_prr_error_gr4', 3.393122061309576),
#  ('avg_prr_error_prev2', 3.3873704121746018),
#  ('related_to_status_prev1', 3.3536819569449707),
#  ('total_errors_prev5', 3.284906690803576),
#  ('error_per_day_prev5', 3.284906690803455),
#  ('last_error_cardreader_relative_prev1', 3.180863596577493),
#  ('avg_cdm_delivery_status_error_prev4', 3.065766600006713),
#  ('avg_cdm_delivery_status_error_prev5', 2.9680235807914435),
#  ('avg_cdm_dispense_amount_distinct_day_prev4', 2.9207176557353933),
#  ('related_total_errors_prev1', 2.920040731162044),
#  ('last_error_cdm_relative_prev5', 2.705572179085911),
#  ('status_count_gr1', 2.647918859001986),
#  ('avg_cdm_dispense_status_error_gr1', 2.634474607007552),
#  ('hours_since_last_prr_error_gr5', 2.5254102347211997),
#  ('avg_cdm_dispense_count_prev3', 2.468562308202938),
#  ('avg_cdm_dispense_count_prev5', 2.45426159944526),
#  ('avg_card_number_gr2', 2.3852072493932885),
#  ('avg_cdm_delivery_status_null_prev3', 2.341961611460618),
#  ('related_to_transactions', 2.178933002023917),
#  ('bna_error_by_day_gr4', 1.9388251331434874),
#  ('avg_cdm_delivery_status_not_taken_prev5', 1.617864259104341),
#  ('bna_error_by_day_prev1', 1.6141121753474166),
#  ('days_since_last_cdm_error', 1.3305938259720438),
#  ('avg_cdm_delivery_status_not_taken_prev4', 1.0979030288577405),
#  ('hours_since_last_bna_error_gr3', 1.0962721055842002),
#  ('last_error_bna_relative_prev4', 1.0845760345869004),
#  ('avg_cdm_dispense_status_null_prev3', 1.0770733814970919),
#  ('related_to_transactions_prev5', 1.0459047168952746),
#  ('hours_since_last_cdm_error_gr2', 0.9765624746361452),
#  ('avg_cdm_error_gr1', 0.9070496256585295),
#  ('avg_reply_count_gr1', 0.8947598745318643),
#  ('avg_cdm_delivery_status_not_taken_gr1', 0.8947553153898737),
#  ('avg_request_count_gr3', 0.8244443227999554),
#  ('hours_since_last_bna_error_prev3', 0.790341048306659),
#  ('avg_bna_vault_count_distinct_day_gr5', 0.6617186431693507),
#  ('distinct_days', 0.6175404095475031),
#  ('bna_error_by_disticnt_day_prev5', 0.613350589058549),
#  ('hours_since_last_prr_error', 0.5522930887697447),
#  ('avg_command_completion_count_gr3', 0.43317068610174364),
#  ('scanner_code_reader', 0.23126977857930442),
#  ('avg_bna_accept_status_null_prev2', 0.10653660203549442),
#  ('days_since_last_prr_error_gr2', 0.08569521202514557),
#  ('days_since_last_prr_error_prev3', 0.07789423378500136),
#  ('avg_bna_accept_count_distinct_day_gr5', 0.0),
#  ('avg_session_error_count_distinct_day_gr5', 0.0),
#  ('avg_front_prepare_count_distinct_day_gr5', 0.0),
#  ('bna_error_by_disticnt_day_gr5', 0.0),
#  ('avg_cdm_dispense_amount_gr5', 0.0),
#  ('avg_cardreader_error_gr5', 0.0),
#  ('avg_receipt_confirm_count_distinct_day_gr4', 0.0),
#  ('avg_ndc_error_gr4', 0.0),
#  ('avg_cdm_dispense_count_gr4', 0.0),
#  ('avg_front_prepare_count_distinct_day_gr4', 0.0),
#  ('avg_cdm_dispense_status_error_gr4', 0.0),
#  ('related_total_errors_gr3', 0.0),
#  ('avg_bna_accept_status_null_gr3', 0.0),
#  ('days_since_last_prr_error_gr3', 0.0),
#  ('avg_command_copletion_count_distinct_day_gr3', 0.0),
#  ('avg_card_capture_count_gr3', 0.0),
#  ('avg_cdm_dispense_amount_distinct_day_gr3', 0.0),
#  ('avg_reply_count_gr3', 0.0),
#  ('avg_request_count_distinct_day_gr3', 0.0),
#  ('avg_cdm_delivery_status_not_taken_gr2', 0.0),
#  ('avg_cdm_dispense_status_null_gr2', 0.0),
#  ('last_error_prr_relative_gr2', 0.0),
#  ('avg_dispence_currency_0_gr2', 0.0),
#  ('avg_cdm_dispense_amount_gr2', 0.0),
#  ('avg_cdm_delivery_status_null_gr2', 0.0),
#  ('avg_receipt_confirm_count_distinct_day_gr1', 0.0),
#  ('avg_command_completion_count_gr1', 0.0),
#  ('related_total_errors_gr1', 0.0),
#  ('error_per_day_gr1', 0.0),
#  ('cdm_error_by_disticnt_day_gr1', 0.0),
#  ('avg_request_count_gr1', 0.0),
#  ('total_errors_gr1', 0.0),
#  ('last_error_bna_relative_prev5', 0.0),
#  ('distinct_days_prev5', 0.0),
#  ('days_since_last_cardreader_error_prev5', 0.0),
#  ('avg_bna_accept_count_prev5', 0.0),
#  ('avg_command_completion_count_prev5', 0.0),
#  ('avg_bna_accept_status_null_prev5', 0.0),
#  ('model_prev5', 0.0),
#  ('age_prev5', 0.0),
#  ('days_since_last_prr_error_prev5', 0.0),
#  ('avg_reply_count_prev5', 0.0),
#  ('days_since_last_cdm_error_prev5', 0.0),
#  ('avg_request_count_prev5', 0.0),
#  ('status_to_transactions_prev4', 0.0),
#  ('avg_bna_vault_count_prev4', 0.0),
#  ('model_prev4', 0.0),
#  ('age_prev4', 0.0),
#  ('transactions_count_prev4', 0.0),
#  ('avg_card_number_distinct_day_prev4', 0.0),
#  ('cdm_label_prev4', 0.0),
#  ('avg_mcrw_error_prev3', 0.0),
#  ('avg_bna_accept_status_null_prev3', 0.0),
#  ('model_prev3', 0.0),
#  ('age_prev3', 0.0),
#  ('avg_card_number_prev3', 0.0),
#  ('avg_cdm_dispense_amount_distinct_day_prev3', 0.0),
#  ('avg_reply_count_prev3', 0.0),
#  ('avg_front_prepare_count_prev3', 0.0),
#  ('related_to_status_prev3', 0.0),
#  ('distinct_days_prev2', 0.0),
#  ('avg_command_completion_count_prev2', 0.0),
#  ('model_prev2', 0.0),
#  ('age_prev2', 0.0),
#  ('hours_since_last_cardreader_error_prev2', 0.0),
#  ('last_error_cdm_relative_prev2', 0.0),
#  ('avg_reply_count_prev2', 0.0),
#  ('avg_request_count_prev2', 0.0),
#  ('non_related_to_status_prev2', 0.0),
#  ('avg_receipt_confirm_count_prev2', 0.0),
#  ('hours_since_last_cdm_error_prev2', 0.0),
#  ('avg_mcrw_error_prev1', 0.0),
#  ('model_prev1', 0.0),
#  ('age_prev1', 0.0),
#  ('avg_bna_accept_status_null', 0.0),
#  ('avg_prr_error', 0.0),
#  ('model', 0.0),
#  ('age', 0.0),
#  ('avg_card_number', 0.0),
#  ('bna_error_by_day', 0.0),
#  ('status_count', 0.0),
#  ('avg_bna_return_count_prev3', -0.03408248592344654),
#  ('avg_cdm_dispense_count_gr2', -0.15966730391341727),
#  ('avg_cdm_error', -0.19737308485712224),
#  ('avg_front_prepare_count_distinct_day_gr1', -0.22298248638988485),
#  ('avg_cdm_dispense_count_distinct_day_gr4', -0.25174436809044787),
#  ('avg_session_error_count', -0.520796044435442),
#  ('avg_front_prepare_count_distinct_day_prev1', -0.7439757023523847),
#  ('last_error_prr_relative', -0.8240237160691402),
#  ('avg_bna_vault_count_prev3', -0.8447767048019017),
#  ('avg_cdm_delivery_status_null_gr5', -0.9897771756632824),
#  ('avg_reply_count_distinct_day_gr3', -1.071673048338804),
#  ('avg_cdm_delivery_count_gr2', -1.0955622746380083),
#  ('avg_bna_error_gr5', -1.1545587946728813),
#  ('cdm_label_gr2', -1.3605316793888087),
#  ('days_since_last_bna_error_prev2', -1.4380899481671854),
#  ('avg_cdm_delivery_status_not_taken_gr5', -1.4531224101621376),
#  ('non_related_total_errors_prev5', -1.5629628436826133),
#  ('avg_dispence_currency_810_gr3', -1.7774554387616002),
#  ('avg_cdm_dispense_status_ok_gr3', -1.7774554387616002),
#  ('cdm_label_gr5', -2.0611230509685323),
#  ('avg_cdm_delivery_status_ok_gr2', -2.0807682833942884),
#  ('avg_bna_error_gr1', -2.118150944322718),
#  ('hours_since_last_cdm_error_gr3', -2.1648600155053184),
#  ('avg_bna_accept_count_prev3', -2.1833385442138793),
#  ('avg_bna_vault_count_prev2', -2.2097695249348646),
#  ('avg_cdm_delivery_count_prev3', -2.337515832039181),
#  ('avg_cdm_delivery_count_gr3', -2.4494661555552697),
#  ('avg_cdm_delivery_status_ok_prev3', -2.4698717933664422),
#  ('avg_cdm_error_prev5', -2.4880984700227535),
#  ('avg_cdm_delivery_status_ok_gr3', -2.506721353488567),
#  ('avg_session_error_count_distinct_day_gr1', -2.698722061075008),
#  ('avg_dispence_currency_0_gr5', -2.7177703093699797),
#  ('related_to_non_related_prev3', -3.1430317255982683),
#  ('avg_cdm_dispense_status_error_gr2', -3.2638759010059366),
#  ('non_related_to_status', -3.2994451965188536),
#  ('avg_dispence_currency_810_gr4', -3.3044924730546397),
#  ('avg_cdm_dispense_status_ok_gr4', -3.3044924730546397),
#  ('transactions_count_gr2', -3.3484004413529687),
#  ('hours_since_last_prr_error_gr3', -3.4013760638313437),
#  ('avg_cdm_dispense_status_null_gr5', -3.4182621444415457),
#  ('days_since_last_bna_error', -3.5492194188011967),
#  ('avg_cdm_dispense_amount', -3.5974774905337124),
#  ('avg_prr_error_gr2', -3.6527142831452357),
#  ('avg_front_prepare_count_gr2', -3.690596002435843),
#  ('cdm_error_by_disticnt_day_gr2', -3.728789370150292),
#  ('days_since_last_cardreader_error_prev2', -3.7491893177837907),
#  ('cdm_label_gr3', -3.824164332291708),
#  ('avg_dispence_currency_810_gr2', -3.8521486985084983),
#  ('avg_cdm_dispense_status_ok_gr2', -3.8521486985084983),
#  ('avg_cdm_delivery_status_not_taken_prev2', -3.8988393222355464),
#  ('avg_cardreader_error_prev5', -3.914797940619861),
#  ('avg_command_completion_count_prev3', -4.004908919034507),
#  ('avg_request_count_prev3', -4.015079767133702),
#  ('cdm_label_gr4', -4.108511525479965),
#  ('avg_cdm_dispense_amount_prev3', -4.267412801886843),
#  ('last_error_bna_relative_prev2', -4.382624466978397),
#  ('days_since_last_bna_error_gr5', -4.398961846046571),
#  ('avg_cdm_dispense_count_distinct_day_prev3', -4.437521969109353),
#  ('prr_error_by_disticnt_day_gr2', -4.5733790156313265),
#  ('avg_command_copletion_count_distinct_day_prev4', -4.647772035527234),
#  ('avg_request_count_distinct_day_prev4', -4.675735865923471),
#  ('avg_dispence_currency_810_prev3', -4.755624966875043),
#  ('avg_cdm_dispense_status_ok_prev3', -4.755624966875043),
#  ('last_error_cardreader_relative_prev4', -4.763803460839654),
#  ('avg_dispence_currency_0', -4.827570224907988),
#  ('days_since_last_cardreader_error_prev1', -4.853998860426865),
#  ('avg_card_number_distinct_day_prev3', -5.016825464942655),
#  ('avg_cardreader_error_prev4', -5.163947547447152),
#  ('avg_request_count_distinct_day_prev1', -5.176593335384797),
#  ('avg_command_copletion_count_distinct_day_prev1', -5.181796410233891),
#  ('avg_cdm_delivery_status_ok_gr4', -5.2141367434873),
#  ('cdm_error_by_day_gr1', -5.248700706562689),
#  ('avg_cdm_delivery_count_gr4', -5.29798703133385),
#  ('avg_cdm_dispense_amount_distinct_day_gr5', -5.316550638087842),
#  ('avg_bna_vault_count_prev5', -5.47964588501962),
#  ('avg_reply_count_distinct_day_prev4', -5.5479552618689825),
#  ('avg_card_capture_count_distinct_day_prev5', -5.634210290565559),
#  ('avg_cdm_dispense_status_null', -5.65735646686648),
#  ('status_count_prev3', -5.754745254498685),
#  ('avg_cdm_delivery_count_distinct_day_prev3', -5.82050602500834),
#  ('avg_receipt_confirm_count_distinct_day', -6.1891204897607945),
#  ('cdm_error_by_day_prev3', -6.276144000549864),
#  ('avg_cdm_dispense_status_null_prev5', -6.379929676011548),
#  ('hours_since_last_prr_error_gr4', -6.4185642443001445),
#  ('avg_cdm_delivery_count_distinct_day_prev2', -6.427771870966595),
#  ('avg_cdm_delivery_status_null', -6.483714628490877),
#  ('avg_prr_error_prev4', -6.491916699874546),
#  ('avg_prr_error_gr1', -6.615130665401638),
#  ('avg_cdm_delivery_status_not_taken_gr3', -6.7465066713920905),
#  ('avg_epp_error_prev5', -6.8299548929746035),
#  ('hours_since_last_prr_error_prev2', -6.885383365104085),
#  ('avg_dispence_currency_0_prev5', -6.924013352553283),
#  ('avg_mcrw_error_prev2', -6.935049761298703),
#  ('avg_reply_count_distinct_day_prev1', -6.937421648248021),
#  ('cardreader_error_by_disticnt_day_prev1', -6.9959537612755955),
#  ('cdm_label_gr1', -7.114462443583634),
#  ('cdm_error_by_disticnt_day_gr5', -7.170246587415437),
#  ('avg_front_prepare_count_gr4', -7.194990984415386),
#  ('hours_since_last_cardreader_error_gr5', -7.2007583336539955),
#  ('avg_bna_vault_count', -7.239968200843487),
#  ('cdm_label_prev5', -7.2425615033617365),
#  ('avg_cdm_delivery_status_unknown_distinct_day_gr1', -7.425967269459646),
#  ('avg_receipt_confirm_count_distinct_day_gr2', -7.439607141958594),
#  ('hours_since_last_cardreader_error_prev3', -7.6390882261410695),
#  ('avg_cardreader_error_gr3', -7.714814204928118),
#  ('avg_card_number_distinct_day_gr2', -7.793879102208318),
#  ('cardreader_error_by_day_prev1', -7.830745238947795),
#  ('avg_card_number_gr4', -7.88429598375188),
#  ('hours_since_last_cardreader_error_gr2', -7.986439489324701),
#  ('avg_card_capture_count_distinct_day_gr5', -8.006139776617731),
#  ('avg_cdm_delivery_status_unknown_distinct_day_gr3', -8.143630800542518),
#  ('avg_cdm_dispense_amount_distinct_day_gr2', -8.167817731425458),
#  ('avg_front_prepare_count_distinct_day', -8.193586358630977),
#  ('related_total_errors_prev3', -8.213292077473469),
#  ('display_type', -8.23938636696757),
#  ('avg_bna_accept_count_distinct_day_gr1', -8.314113689237113),
#  ('distinct_days_prev1', -8.400530417452924),
#  ('avg_bna_vault_count_distinct_day_gr3', -8.498212801038516),
#  ('avg_cdm_dispense_status_error_prev5', -8.612504891024741),
#  ('prr_error_by_day_prev2', -8.694687711685717),
#  ('status_count_gr5', -8.78967167357438),
#  ('avg_dispence_currency_810_prev2', -8.798830811359199),
#  ('avg_cdm_dispense_status_ok_prev2', -8.798830811359199),
#  ('avg_bna_accept_count_distinct_day_prev4', -8.806507593766005),
#  ('avg_card_number_prev5', -8.858408974489258),
#  ('avg_epp_error_prev2', -8.923453922704793),
#  ('avg_cdm_dispense_count_prev2', -8.989177677478896),
#  ('avg_cdm_delivery_count_prev2', -8.999951374761597),
#  ('last_error_prr_relative_prev5', -9.06176003303114),
#  ('avg_cdm_delivery_status_ok_prev2', -9.068160662030962),
#  ('avg_cdm_delivery_count_distinct_day_gr3', -9.081131603675612),
#  ('non_related_to_status_prev1', -9.108062327342843),
#  ('avg_bna_accept_count', -9.129498065991298),
#  ('avg_cdm_delivery_status_unknown_distinct_day_gr5', -9.222375591597636),
#  ('avg_session_error_count_gr5', -9.223066541626427),
#  ('non_related_total_errors_prev2', -9.286582359762543),
#  ('avg_cdm_delivery_status_null_prev5', -9.29500681102328),
#  ('avg_bna_accept_status_null_prev4', -9.355093816139554),
#  ('related_to_non_related_prev4', -9.364906934409278),
#  ('avg_cdm_delivery_status_unknown_gr5', -9.613283007147785),
#  ('avg_cdm_dispense_count_distinct_day_gr2', -9.827793722176668),
#  ('avg_receipt_confirm_count_distinct_day_prev5', -9.883219101820996),
#  ('related_to_transactions_gr3', -10.045195024617051),
#  ('avg_cdm_dispense_count_distinct_day_prev2', -10.063305997304191),
#  ('avg_cardreader_error_prev1', -10.099112082977916),
#  ('status_to_transactions_gr1', -10.491271920909933),
#  ('days_since_last_cardreader_error_gr3', -10.53079934051622),
#  ('avg_cdm_delivery_status_not_taken_prev3', -10.569804155287807),
#  ('last_error_cdm_relative_prev1', -10.629683994446104),
#  ('avg_command_copletion_count_distinct_day_prev5', -10.636419241513373),
#  ('related_total_errors_gr5', -10.669159503242106),
#  ('avg_request_count_distinct_day_prev5', -10.669448357414455),
#  ('avg_receipt_confirm_count', -10.764522694473143),
#  ('avg_reply_count_distinct_day_gr5', -10.891601227280889),
#  ('hours_since_last_bna_error_prev5', -11.138909865440402),
#  ('related_total_errors_gr2', -11.282086888826536),
#  ('avg_reply_count_distinct_day_prev5', -11.399633049056554),
#  ('days_since_last_bna_error_prev5', -11.484541525352245),
#  ('avg_prr_error_prev3', -11.50925845280492),
#  ('cdm_error_by_disticnt_day_prev1', -11.63452804866958),
#  ('avg_bna_accept_count_prev2', -11.713866862622096),
#  ('avg_card_capture_count_distinct_day_gr3', -11.760141118836078),
#  ('atm_id', -11.809000558064083),
#  ('error_per_day_prev3', -11.980050517263262),
#  ('total_errors_prev3', -11.980050517263335),
#  ('status_to_transactions_prev1', -12.147274406510876),
#  ('avg_cdm_delivery_status_unknown_distinct_day', -12.212066050241638),
#  ('avg_hasp_error_prev2', -12.281467221700726),
#  ('transactions_count_prev2', -12.35241169898676),
#  ('avg_front_prepare_count_distinct_day_prev4', -12.366426978161837),
#  ('avg_cdm_delivery_status_null_gr1', -12.397346533081063),
#  ('avg_receipt_confirm_count_distinct_day_prev3', -12.5200903659311),
#  ('avg_session_error_count_distinct_day_prev4', -12.521088663394256),
#  ('avg_request_count_distinct_day_gr5', -12.605914758937814),
#  ('avg_session_error_count_gr4', -12.644952161651595),
#  ('avg_command_copletion_count_distinct_day_gr5', -12.714456338023181),
#  ('avg_bna_vault_count_prev1', -12.759281620594257),
#  ('avg_cdm_dispense_status_null_gr1', -12.81537491137044),
#  ('hours_since_last_cardreader_error_gr1', -12.888448802827103),
#  ('avg_cdm_delivery_count_prev4', -12.900811158595822),
#  ('error_per_day_gr2', -12.90941092573599),
#  ('total_errors_gr2', -12.909410925735997),
#  ('avg_cdm_delivery_status_ok_prev4', -12.98823657191447),
#  ('avg_cdm_delivery_count_distinct_day_gr2', -13.031130774177615),
#  ('transactions_count_gr5', -13.282509114440336),
#  ('avg_cdm_dispense_status_error_prev1', -13.291549182088543),
#  ('avg_dispence_currency_0_gr1', -13.300242817536052),
#  ('avg_bna_vault_count_distinct_day_prev3', -13.508261467918365),
#  ('last_error_cdm_relative_gr2', -13.569672413056615),
#  ('avg_cdm_delivery_count_distinct_day_gr4', -13.66220257826951),
#  ('hours_since_last_cdm_error_gr5', -14.001685113767678),
#  ('days_since_last_prr_error_gr5', -14.337572929753154),
#  ('avg_session_error_count_distinct_day', -14.437643819238282),
#  ('hours_since_last_cardreader_error_prev1', -14.461729643854767),
#  ('prr_error_by_day_gr1', -14.532419213448888),
#  ('cdm_error_by_day_prev5', -14.99800342326198),
#  ('avg_front_prepare_count_distinct_day_prev3', -15.134902595733955),
#  ('avg_cdm_delivery_status_error_prev1', -15.191825936049327),
#  ('avg_cdm_dispense_count_gr3', -15.266132164512316),
#  ('avg_prr_error_gr5', -15.351126383966715),
#  ('avg_bna_accept_count_gr1', -16.155697605406818),
#  ('avg_front_prepare_count_prev2', -16.164970769171692),
#  ('avg_session_error_count_prev5', -16.39398418950029),
#  ('days_since_last_cdm_error_gr4', -16.47686309460765),
#  ('cardreader_error_by_disticnt_day_gr3', -16.61980998593964),
#  ('avg_bna_accept_status_null_gr2', -16.636259908107284),
#  ('last_error_bna_relative_gr5', -16.656297638861275),
#  ('avg_cdm_dispense_amount_gr1', -16.71277625977121),
#  ('days_since_last_cdm_error_prev4', -16.825110903833863),
#  ('avg_dispence_currency_810_prev4', -17.196741226309985),
#  ('avg_cdm_dispense_status_ok_prev4', -17.196741226309985),
#  ('related_to_status_gr1', -17.244685506143764),
#  ('avg_front_prepare_count_distinct_day_prev2', -17.310302685064574),
#  ('avg_ndc_error_prev1', -17.35765288867169),
#  ('avg_bna_accept_count_prev1', -17.42858680412653),
#  ('days_since_last_cardreader_error', -17.55792946852273),
#  ('prr_error_by_day_gr5', -17.579191728609864),
#  ('avg_session_error_count_gr3', -17.63192400879689),
#  ('avg_hasp_error_prev1', -17.71892910624498),
#  ('avg_session_error_count_distinct_day_gr4', -17.85234962231209),
#  ('avg_session_error_count_distinct_day_prev1', -17.85484040954533),
#  ('avg_bna_error_prev3', -17.93068585409568),
#  ('cardreader_error_by_disticnt_day_prev2', -17.93156710741042),
#  ('avg_cardreader_error_gr2', -18.025094201388374),
#  ('last_error_bna_relative_gr2', -18.026830098742817),
#  ('avg_cdm_delivery_status_error_gr5', -18.130267328967918),
#  ('avg_cdm_dispense_status_null_prev1', -18.281711159461253),
#  ('total_errors_gr5', -18.431873502568646),
#  ('error_per_day_gr5', -18.43187350256869),
#  ('avg_request_count_prev1', -18.545126714860277),
#  ('avg_command_completion_count_prev1', -18.560230686468287),
#  ('avg_reply_count_distinct_day_gr1', -18.760782192339875),
#  ('avg_cdm_dispense_amount_distinct_day_prev5', -18.843184616930397),
#  ('avg_dispence_currency_0_prev1', -18.90544644633592),
#  ('avg_mcrw_error_gr1', -18.99433930147316),
#  ('avg_ndc_error_gr1', -18.99433930147316),
#  ('non_related_to_status_gr1', -18.99433930147316),
#  ('avg_cdm_dispense_amount_prev4', -19.03649381980079),
#  ('avg_command_completion_count_prev4', -19.316799744429563),
#  ('avg_request_count_prev4', -19.35850481360257),
#  ('cdm_error_by_day_gr5', -19.3969392904119),
#  ('bna_error_by_disticnt_day_gr2', -19.557295171577277),
#  ('days_since_last_bna_error_prev1', -19.708257490466043),
#  ('avg_receipt_confirm_count_gr1', -19.802795244933833),
#  ('cdm_error_by_day_prev4', -19.842495764587152),
#  ('avg_card_capture_count_prev1', -19.847707094842328),
#  ('cdm_error_by_day_prev1', -19.919522306671833),
#  ('bna_error_by_disticnt_day_gr4', -19.94158182847562),
#  ('avg_session_error_count_distinct_day_prev2', -20.015181502569593),
#  ('related_to_status_prev2', -20.345969724432795),
#  ('avg_request_count_distinct_day_gr1', -20.824410340593104),
#  ('avg_card_capture_count_gr1', -20.87882679366116),
#  ('avg_cdm_delivery_status_null_prev1', -20.901093740894062),
#  ('avg_cdm_dispense_count_distinct_day', -21.110403804023782),
#  ('avg_command_copletion_count_distinct_day_gr1', -21.12114987777562),
#  ('days_since_last_cardreader_error_prev3', -21.175642859219984),
#  ('avg_bna_return_count_prev4', -21.197819524871576),
#  ('distinct_days_gr3', -21.378249740337417),
#  ('hours_since_last_prr_error_prev5', -21.417772731508194),
#  ('avg_cdm_delivery_count_distinct_day', -21.50910838391555),
#  ('avg_cdm_dispense_amount_gr3', -21.779980903494444),
#  ('days_since_last_prr_error_gr4', -21.981383900691267),
#  ('avg_card_number_distinct_day_prev5', -22.073748011159314),
#  ('avg_front_prepare_count_gr3', -22.20440596042966),
#  ('avg_reply_count_prev1', -22.395217089743277),
#  ('related_to_non_related_prev1', -22.59173536186228),
#  ('cdm_error_by_disticnt_day', -22.64909490727189),
#  ('distinct_days_gr5', -22.9523228968537),
#  ('avg_card_capture_count_distinct_day_gr4', -23.423780668541383),
#  ('avg_card_number_prev2', -23.70917783108004),
#  ('avg_hasp_error_prev5', -23.93022866912399),
#  ('avg_receipt_confirm_count_gr4', -23.939399679086087),
#  ('days_since_last_cardreader_error_gr1', -24.053847062110272),
#  ('avg_reply_count_gr5', -24.18339253518746),
#  ('status_count_gr4', -24.409695930158414),
#  ('avg_receipt_confirm_count_prev3', -24.489024456597257),
#  ('avg_reply_count_prev4', -24.537910636571898),
#  ('avg_bna_accept_count_distinct_day_prev3', -24.600039801744273),
#  ('avg_cdm_dispense_count_distinct_day_gr3', -24.880213677997812),
#  ('avg_cdm_dispense_count_prev4', -24.882757061695987),
#  ('avg_cdm_delivery_status_error_gr4', -25.033990976897595),
#  ('avg_cdm_dispense_amount_prev2', -25.034599605573412),
#  ('hours_since_last_bna_error_gr2', -25.50504503764138),
#  ('avg_request_count_gr5', -25.793724385651416),
#  ('hours_since_last_prr_error_prev4', -25.890808105532034),
#  ('avg_card_capture_count_gr2', -25.92229864749901),
#  ('bna_error_by_day_prev3', -26.0137667884856),
#  ('avg_command_completion_count_gr5', -26.07469426415807),
#  ('avg_bna_vault_count_gr5', -26.545240959453903),
#  ('hours_since_last_cdm_error_prev4', -26.89898058612576),
#  ('last_error_bna_relative_gr1', -27.277030709961565),
#  ('bna_error_by_day_gr3', -27.411113224231812),
#  ('cardreader_error_by_disticnt_day_gr2', -27.767773595126975),
#  ('avg_bna_return_count_prev5', -27.87715154920197),
#  ('avg_bna_vault_count_distinct_day_prev4', -27.92844847011799),
#  ('related_to_status_gr3', -27.936248430791764),
#  ('prr_error_by_disticnt_day_prev3', -28.09178887593897),
#  ('avg_bna_accept_count_distinct_day_prev5', -28.49640914178257),
#  ('last_error_prr_relative_prev1', -28.910496134174974),
#  ('avg_front_prepare_count_prev1', -29.219177809769533),
#  ('distinct_days_gr1', -29.288106651474735),
#  ('hours_since_last_cardreader_error_gr3', -29.40035888090713),
#  ('cardreader_error_by_disticnt_day_gr4', -30.1540294836237),
#  ('related_to_status_gr4', -30.374725591039166),
#  ('status_count_prev2', -30.44768234498472),
#  ('avg_bna_accept_count_gr5', -30.72801869437813),
#  ('avg_cdm_dispense_amount_gr4', -30.733263492763463),
#  ('related_to_transactions_gr4', -31.285647628356376),
#  ('avg_bna_vault_count_distinct_day_gr1', -31.31631858848741),
#  ('avg_bna_return_count_distinct_day_gr4', -31.421693953096174),
#  ('avg_card_capture_count_distinct_day_prev2', -31.70709270999949),
#  ('avg_session_error_count_distinct_day_prev3', -31.717371078374136),
#  ('avg_cdm_delivery_status_unknown_distinct_day_prev3', -32.09884092689016),
#  ('avg_front_prepare_count_gr1', -32.166469223297746),
#  ('prr_error_by_day_gr2', -32.56703988549124),
#  ('avg_cdm_dispense_count_distinct_day_gr5', -32.59505454493393),
#  ('hours_since_last_cardreader_error', -33.364026254251804),
#  ('avg_cdm_delivery_status_unknown_prev2', -33.39868251986226),
#  ('avg_card_number_gr1', -33.450515365831805),
#  ('last_error_prr_relative_prev4', -33.50625428391985),
#  ('avg_cdm_delivery_status_unknown_prev4', -33.52011244857114),
#  ('cdm_error_by_disticnt_day_prev5', -33.648707861705),
#  ('hours_since_last_bna_error_gr1', -33.76135444640113),
#  ('avg_bna_error_gr3', -33.980706342597514),
#  ('avg_front_prepare_count_distinct_day_prev5', -34.202095236893825),
#  ('avg_bna_accept_status_null_gr1', -34.266947477790694),
#  ('cardreader_error_by_day_gr1', -34.54353206629681),
#  ('related_to_status', -34.72718625763944),
#  ('prr_error_by_disticnt_day_prev5', -34.94511202013005),
#  ('cardreader_error_by_disticnt_day_prev4', -35.861953740399905),
#  ('last_error_bna_relative', -35.87752305938885),
#  ('last_error_bna_relative_prev3', -36.06846756435254),
#  ('avg_mcrw_error', -36.70313127895518),
#  ('avg_ndc_error', -36.77527628295453),
#  ('avg_card_capture_count_distinct_day_prev4', -36.95699473331388),
#  ('status_to_transactions_prev3', -36.96218752297784),
#  ('hours_since_last_bna_error_gr5', -37.07922084842716),
#  ('avg_bna_vault_count_gr1', -37.52819949936599),
#  ('cardreader_error_by_disticnt_day_prev3', -38.56310881394777),
#  ('cdm_error_by_disticnt_day_gr4', -38.878660222848644),
#  ('cardreader_error_by_day_gr3', -39.72108299485878),
#  ('avg_cardreader_error_prev2', -40.19502333587292),
#  ('avg_bna_return_count_distinct_day_prev2', -40.3971469330929),
#  ('prr_error_by_disticnt_day', -40.92018105592358),
#  ('avg_cdm_delivery_status_error_gr3', -41.187161485543704),
#  ('cdm_error_by_disticnt_day_prev4', -41.34237128275427),
#  ('avg_bna_error_prev1', -41.711713958079535),
#  ('avg_bna_vault_count_distinct_day_gr2', -42.17466070318178),
#  ('avg_cdm_delivery_count_distinct_day_gr5', -42.354526262956014),
#  ('avg_cdm_delivery_status_unknown_distinct_day_prev5', -42.413410775040624),
#  ('hours_since_last_bna_error', -42.5942846413605),
#  ('prr_error_by_day_gr4', -43.202315237471524),
#  ('hours_since_last_cdm_error_gr4', -43.647379774372894),
#  ('avg_bna_vault_count_distinct_day_prev5', -43.68517450811988),
#  ('avg_card_number_distinct_day_gr1', -43.81708607511797),
#  ('transactions_count_prev5', -44.75007483167216),
#  ('bna_error_by_day_gr2', -45.191897939796576),
#  ('avg_cdm_dispense_amount_prev1', -45.52144578269288),
#  ('avg_bna_accept_count_distinct_day_gr4', -46.400591032603145),
#  ('non_related_total_errors_gr1', -46.732084928373546),
#  ('avg_cdm_dispense_status_error_prev4', -46.95383662570734),
#  ('transactions_count_prev3', -48.03940144772517),
#  ('avg_cdm_delivery_status_unknown_distinct_day_prev1', -48.20777229226282),
#  ('hours_since_last_cdm_error', -48.2531943378781),
#  ('last_error_cdm_relative', -48.496217155308535),
#  ('avg_bna_vault_count_distinct_day_gr4', -48.87320540741407),
#  ('status_to_transactions_gr3', -48.90326778991311),
#  ('avg_bna_return_count_distinct_day_gr2', -48.91766623186515),
#  ('cdm_error_by_disticnt_day_prev3', -49.50258805224289),
#  ('last_error_bna_relative_prev1', -49.69427439069103),
#  ('avg_receipt_confirm_count_gr2', -51.63532736909529),
#  ('cardreader_error_by_day_gr4', -51.664513553556205),
#  ('avg_cdm_dispense_status_error_gr5', -51.779627335062415),
#  ('cardreader_error_by_disticnt_day_gr1', -55.391980111947966),
#  ('last_error_prr_relative_prev2', -55.98303078123845),
#  ('avg_bna_accept_count_distinct_day_gr2', -56.32260601823099),
#  ('non_related_to_status_prev5', -57.699650640824586),
#  ('avg_hasp_error_prev4', -58.52606537735888),
#  ('avg_bna_return_count_gr3', -59.38915365894849),
#  ('avg_session_error_count_distinct_day_gr3', -60.81615716091986),
#  ('non_related_to_transactions_prev3', -60.960890878975576),
#  ('status_to_transactions', -63.1981210992338),
#  ('non_related_to_status_prev4', -64.09061521028046),
#  ('avg_bna_error', -64.11423407938577),
#  ('avg_ndc_error_prev4', -64.26874888552419),
#  ('cardreader_error_by_disticnt_day', -65.32189395092031),
#  ('avg_prr_error_gr3', -68.36841564361488),
#  ('cardreader_error_by_disticnt_day_gr5', -71.39318170665089),
#  ('avg_cdm_error_prev2', -71.44546690204746),
#  ('non_related_total_errors_prev3', -71.44649316129569),
#  ('non_related_to_transactions_prev1', -72.76381389749297),
#  ('cdm_error_by_day_gr2', -73.36264922291295),
#  ('avg_bna_return_count_distinct_day_prev3', -83.76260425679024),
#  ('last_error_cdm_relative_gr3', -88.94852876718781),
#  ('prr_error_by_disticnt_day_prev1', -98.52023827938616),
#  ('last_error_prr_relative_gr3', -106.38917245751365),
#  ('avg_epp_error', -108.30637407477757),
#  ('bna_error_by_disticnt_day_prev4', -115.49106015673249),
#  ('cardreader_error_by_disticnt_day_prev5', -120.86815717579267),
#  ('non_related_to_transactions_gr1', -121.62394728578445),
#  ('bna_error_by_disticnt_day_prev2', -126.13654645805003),
#  ('avg_mcrw_error_prev5', -128.32992934386505),
#  ('avg_bna_return_count_distinct_day_gr3', -195.7747924087734),
#  ('avg_mcrw_error_gr4', -240.94466778941248),
#  ('non_related_to_status_gr4', -240.94466778941248),
#  ('non_related_to_transactions_gr4', -240.94466778941307),
#  ('non_related_total_errors_gr4', -240.94466778941347),
#  ('related_to_non_related_gr4', -240.9446677894135),
#  ('avg_epp_error_prev4', -275.45568003594616)]
